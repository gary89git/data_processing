# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Swimmer-Model" data-toc-modified-id="Swimmer-Model-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Swimmer Model</a></span></li><li><span><a href="#Questions" data-toc-modified-id="Questions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Questions</a></span></li><li><span><a href="#Fig-1-1&amp;1-2-Truncation-Error:-$\frac{d}{dx}-\sin-x$" data-toc-modified-id="Fig-1-1&amp;1-2-Truncation-Error:-$\frac{d}{dx}-\sin-x$-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Fig 1-1&amp;1-2 Truncation Error: $\frac{d}{dx} \sin x$</a></span></li><li><span><a href="#Fig-1-3-$sin(x)$-approx" data-toc-modified-id="Fig-1-3-$sin(x)$-approx-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Fig 1-3 $sin(x)$ approx</a></span></li><li><span><a href="#Fig-1-4-Error-bar" data-toc-modified-id="Fig-1-4-Error-bar-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Fig 1-4 Error bar</a></span></li><li><span><a href="#Fig-1-5-roots" data-toc-modified-id="Fig-1-5-roots-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Fig 1-5 roots</a></span></li><li><span><a href="#Fig-1-6" data-toc-modified-id="Fig-1-6-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Fig 1-6</a></span></li><li><span><a href="#Fig-1-14" data-toc-modified-id="Fig-1-14-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Fig 1-14</a></span></li><li><span><a href="#Fig-1-15" data-toc-modified-id="Fig-1-15-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Fig 1-15</a></span></li><li><span><a href="#Fig-1-16-&amp;-1-17" data-toc-modified-id="Fig-1-16-&amp;-1-17-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Fig 1-16 &amp; 1-17</a></span></li><li><span><a href="#Fig-2-2" data-toc-modified-id="Fig-2-2-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Fig 2-2</a></span></li><li><span><a href="#Fig-2-5" data-toc-modified-id="Fig-2-5-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Fig 2-5</a></span></li><li><span><a href="#Fig-2-16" data-toc-modified-id="Fig-2-16-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Fig 2-16</a></span></li><li><span><a href="#Fig-2-20" data-toc-modified-id="Fig-2-20-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Fig 2-20</a></span></li><li><span><a href="#Fig-2-24-&amp;-2-25" data-toc-modified-id="Fig-2-24-&amp;-2-25-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Fig 2-24 &amp; 2-25</a></span></li><li><span><a href="#Fig-2-26" data-toc-modified-id="Fig-2-26-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Fig 2-26</a></span></li><li><span><a href="#Fig-2-27" data-toc-modified-id="Fig-2-27-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Fig 2-27</a></span></li><li><span><a href="#Fig-2-29" data-toc-modified-id="Fig-2-29-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Fig 2-29</a></span></li><li><span><a href="#Fig-2-30" data-toc-modified-id="Fig-2-30-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Fig 2-30</a></span></li><li><span><a href="#Fig-2-31" data-toc-modified-id="Fig-2-31-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Fig 2-31</a></span></li><li><span><a href="#Fig-2-35" data-toc-modified-id="Fig-2-35-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Fig 2-35</a></span></li><li><span><a href="#Fig-2-36" data-toc-modified-id="Fig-2-36-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Fig 2-36</a></span></li><li><span><a href="#T1/T1" data-toc-modified-id="T1/T1-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>T1/T1</a></span></li></ul></div>

# %% [markdown]
# # Plots for Textbooks

# %%
import numpy as np
import random
import os
import openpyxl as opxl
import pandas as pd
# from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as pl
from plotly.offline import iplot, plot, init_notebook_mode
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.io as pio
import plotly
plotly.tools.set_credentials_file(username='garyhan', api_key='jb6utiwqOF7F3bAuf1Td')
init_notebook_mode(connected=True)

from scipy import fftpack
from scipy.stats import norm
import math
from math import factorial
from math import sin
from math import cos
from math import log
from math import exp
from math import sinh
#import Image
import numpy as np

#rc('text', usetex=True)

# def drange(start, stop, step):
#      r = start
#      out = []
#      while r < stop:
#      	out.append(r)
#      	r += step
#      return out

# %% [markdown]
# ## Swimmer Model

# %%
'''
a = 100
def displacement(x, v_ratio, beta):
    return v_ratio * (x - x**3/(3.0*a**2) + 2*a/3.0) / cos(beta) - (x + a) * sin(beta) / cos(beta)
    
x = drange(-100.0, 100.0, 0.5)
y_1 = np.zeros(len(x))
y_2 = np.zeros(len(x))
y_3 = np.zeros(len(x))
y_4 = np.zeros(len(x))

for i in range(0, len(x)):
    y_1[i] = displacement(x[i], 1.3, -math.pi/6)
    y_2[i] = displacement(x[i], 1.3, 0)
    y_3[i] = displacement(x[i], 1.3, math.pi/3)
    y_4[i] = displacement(x[i], 1.3, math.pi/2.2)


fig,ax = pl.subplots()
ax.plot(x, y_1, "r-", lw=1)
ax.plot(x, y_2, 'g-', lw=1)
ax.plot(x, y_3, 'b-', lw=1)
ax.plot(x, y_4, 'm-', lw=1)
ax.plot([-100, -100], [-500,2000], "k-", lw=4)
ax.plot([100, 100], [-500,2000], "k-", lw=4)
ax.plot([0,0],[-500,2000],"k-",lw=1)
ax.arrow(0,484,0,0.1, fc="k", ec="k", head_width=4, head_length=15, lw=1)
pl.xlim(-140,150)
pl.ylim(-200,500)
pl.xticks([-100, 0, 100],[r"$-a$",'0', r"$a$"])
pl.tick_params(axis='x', which='both', top='false')
pl.tick_params(axis='y', which='both', left='false', right='false', labelleft='false')
pl.xlabel(r"$x$",fontsize=16, labelpad=0)
# pl.ylabel(r"$y(x)$",fontsize=16, labelpad=0)
pl.text(0, 515, r'$y(x)$', horizontalalignment='center',fontsize=15)
ax.arrow(138,0,0.1,0, fc="k", ec="k", head_width=18, head_length=4, lw=1)
ax.plot([-140, 140], [0, 0], 'k-', lw=1)
pl.text(147, -15, r'$x$', horizontalalignment='center',fontsize=15)
pl.text(-124, -42, r'$(-a,0)$', horizontalalignment='center',fontsize=15)
pl.text(118, -42, r'$(a,0)$', horizontalalignment='center',fontsize=15)

temp = 100
x_w = drange(-100.0, 100.0, 1.0)
y_w = np.zeros(len(x_w))
for i in range(0, len(x_w)):
    y_w[i] = -0.013*x_w[i]**2+440.0
#ax.plot(x_w, y_w, 'k-', lw=0.5)
wx = drange(-95.0,100.0,12.0)
wy = np.zeros(len(wx))
for i in range(0, len(wx)):
    wy[i] = -0.013*wx[i]**2+440.0-5-305
    ax.arrow(wx[i]-1, 305, 0, wy[i]-1, fc="#D1D0CE", ec="#D1D0CE", head_width=2, head_length=5, lw=2)

# pl.text(5, 190, r'$y(x)=\frac{v_0}{v_S}\left(x-\frac{x^3}{3a^2}+\frac{2a}{3}\right)$', fontsize=18)
pl.text(-65, 100, r'$\beta>0$', color="r", fontsize=15)
pl.text(40, 170, r'$\beta=0$', color="g", fontsize=15)
pl.text(40, 55, r'$\beta=\beta_0$', color="b", fontsize=15)
pl.text(-65, -125, r'$\beta<\beta_0$', color="m", fontsize=15)
# pl.text(103, 72, r'$\frac{v_0}{v_S}\frac{4a}{3}$', fontsize=15)
pl.text(-50, 280, r'$v_R=v_0\left(1-\frac{x^2}{a^2}\right)$', horizontalalignment='center', fontsize=15)
pl.text(2, 305+wy[8], r'$v_0$', fontsize=15)
# ax.arrow(110, 50, 0, -45, head_width=2, head_length=4, lw=1)
# ax.arrow(110, y_2[-1]-50, 0, 45, head_width=2, head_length=4, lw=1)
ax.axis('off')

pl.show()
# fig.savefig('Drawing21.png', dpi=500, bbox_inches='tight')
'''

# %%
x = np.linspace(0,10,1001)
y = 2.019 * x * (1 + np.exp(2.019*x))
xx = np.linspace(0,200,11)
xx = np.linspace(1,6,501)

# %%
trace0 = go.Scatter(
    x = xx,
    y = (np.sqrt(xx)-1)**2,
    mode = 'lines',
    line = dict(color = 'green')
)
trace1 = go.Scatter(
    x = np.linspace(2,6,301),
    y = (np.sqrt(np.linspace(2,6,301))-np.sqrt(2))**2,
    mode = 'lines',
    line = dict(color = 'blue')
)
trace2 = go.Scatter(
    x = np.linspace(3,6,201),
    y = (np.sqrt(np.linspace(3,6,201))-np.sqrt(3))**2,
    mode = 'lines',
    line = dict(color = 'red')
)
# trace3 = go.Scatter(
#     x = xx,
#     y = (xx - 4) * np.exp(-4) - 4,
#     mode = 'lines',
#     line = dict(color = 'blue')
# )
# trace4 = go.Scatter(
#     x = xx,
#     y = (xx - 1.019) * np.exp(-1.019) - 1.019,
#     mode = 'lines',
#     line = dict(color = 'blue')
# )
# trace5 = go.Scatter(
#     x = [0,200],
#     y = [0,0],
#     mode = 'lines',
#     line = dict(color = 'red')
# )

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 6],
#         exponentformat = 'power',
        ticks = 'inside',
#         dtick = 1,
        mirror = 'ticks',
        title = r'$\Large v_0$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
        range = [0, 2],
#         exponentformat = 'power',
        ticks = 'inside',
#         dtick = 2,
        mirror = 'ticks',
        title = r'$\Large v_1$',
#         ticktext=[0, 2, 4, 6, 8, 10, 12],
#         tickvals=[0, 2e9, 4e9, 6e9, 8e9, 10e9, 12e9],
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    showlegend=False,
    autosize=False,
    width=700,
    height=400,
    margin=go.layout.Margin(
        l=80,
        r=20,
        b=40,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0,trace1,trace2], layout=layout)
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/Desktop/f1.png', format='png', scale=5)
# print("Done saving image!")

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 200],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 50,
        mirror = 'ticks',
        title = r'$\Large v_0$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
        range = [0,40],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 10,
        mirror = 'ticks',
        title = r'$\Large v_3$',
#         ticktext=[0, 2, 4, 6, 8, 10, 12],
#         tickvals=[0, 2e9, 4e9, 6e9, 8e9, 10e9, 12e9],
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    legend=dict(
        x=0.35,
        y=0.95,
        traceorder='normal',
#         font=dict(
#             family='Arial',
#             size=18
#             color='blue'
#         ),
#         bgcolor='#E2E2E2',
#         bordercolor='black',
#         borderwidth=1
    ),
    showlegend=False,
    autosize=False,
    width=700,
    height=400,
    margin=go.layout.Margin(
        l=80,
        r=20,
        b=60,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace1,trace2, trace4,trace5], layout=layout)
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/Desktop/f1.png', format='png', scale=5)
# print("Done saving image!")

# %% [markdown]
# ## Questions

# %%
x = np.linspace(0,2,401)
y = 7.123**(-x**2) - x**4 * np.cos(x**2) - 5.7979

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 1
    )
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large x$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial',
#             size=40
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-8, 8],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 2,
        mirror = 'ticks',
        title = '$\large y$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial',
#             size=22
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
#     legend=dict(
#         x=0.75,
#         y=0.06,
#         traceorder='normal',
#         font=dict(
#             family='Arial',
# #             size=20,
#             color='black'
#         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
#         borderwidth=1
#     ),
    autosize=False,
    width=800,
    height=400,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=40,
        t=20,
        pad=2
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Q1-2')
iplot(fig)
# pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/q1-2.png', format='png', scale=5)
# print("Done saving image!")

# %% [markdown]
# ## Fig 1-1&1-2 Truncation Error: $\frac{d}{dx} \sin x$

# %%
h = np.array([2**-i for i in range(1,51)])
err = abs((np.sin(1+h) - np.sin(1-h)) / (2 * h) - cos(1))
errest = np.array(abs(h**2 * cos(1))/6)
errextr = abs(((np.sin(1+h) - np.sin(1-h)) * 2 / h - (np.sin(1+2*h) - np.sin(1-2*h)) / (4*h)) / 3 - cos(1))
# print(err)

# %%
trace0 = go.Scatter(
    x = h,
    y = errest,
    mode = 'lines+markers',
    line = dict(
        color = 'red',
        width = 1.5
    ),
    name = 'Error Estimate',
    marker = dict(
        size = 8,
        color = 'rgba(0, 0, 0, 0)',
        line = dict(
            width = 2,
            color = 'red'
        )
    )
)
trace1 = go.Scatter(
    x = h,
    y = err,
    mode = 'lines+markers',
    line = dict(
        color = 'blue',
        width = 1.5
#         dash = 'dot'
    ),
    marker = dict(
        size = 6,
#         color = 'rgba(0, 0, 0, 0)',
        line = dict(
#             width = 1,
            color = 'red'
        )
    ),
    name = 'Error'
)

# %%
data = [trace1,trace0]
layout = go.Layout(
    xaxis=dict(
        range = [-16.1, 0],
        exponentformat = 'power',
        ticks = 'inside',
        mirror = 'ticks',
        title = '$h$',
        type = 'log',
        titlefont=dict(
#             family='Arial',
            size=40
#             color='#7f7f7f'
        ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-37, 0],
        exponentformat = 'power',
        ticks = 'inside',
        dtick = 6,
        mirror = 'ticks',
        title = 'Error',
        type = 'log',
        titlefont=dict(
            family='Arial',
#             size=22
#             color='#7f7f7f'
        ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
    ),
    legend=dict(
        x=0.75,
        y=0.06,
        traceorder='normal',
        font=dict(
            family='Arial',
#             size=20,
            color='black'
        ),
#         bgcolor='#E2E2E2',
#         bordercolor='black',
        borderwidth=1
    ),
    autosize=False,
    width=800,
    height=500,
    margin=go.layout.Margin(
        l=60,
        r=20,
        b=40,
        t=20,
        pad=2
    )
)
fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='Fig1-1')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-1.png', format='png', scale=5)
print("Done saving image!")

# %%
trace2 = go.Scatter(
    x = h,
    y = err,
    mode = 'lines+markers',
    line = dict(
        color = 'blue',
        width = 1.5
#         dash = 'dot'
    ),
    marker = dict(
        size = 6,
#         color = 'rgba(0, 0, 0, 0)',
        line = dict(
#             width = 1,
            color = 'red'
        )
    ),
    name = 'Error for centered difference'
)
trace3 = go.Scatter(
    x = h,
    y = errextr,
    mode = 'lines+markers',
    line = dict(
        color = 'red',
        width = 1.5
    ),
    name = 'Error in extrapolated formula',
    marker = dict(
        size = 8,
        color = 'rgba(0, 0, 0, 0)',
        line = dict(
            width = 2,
            color = 'red'
        )
    )
)

# %%
data = [trace2,trace3]
layout = go.Layout(
    xaxis=dict(
        range = [-16.1, 0],
        exponentformat = 'power',
        ticks = 'inside',
        mirror = 'ticks',
        title = '$h$',
        type = 'log',
        titlefont=dict(
#             family='Arial',
#             size=22
#             color='#7f7f7f'
        ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-14.1, 0],
        exponentformat = 'power',
        ticks = 'inside',
        dtick = 2,
        mirror = 'ticks',
        title = 'Error',
        type = 'log',
        titlefont=dict(
            family='Arial'
#             size=22
#             color='#7f7f7f'
        ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
    ),
    legend=dict(
        x=0.02,
        y=0.06,
        traceorder='normal',
        font=dict(
#             family='Arial',
#             size=20,
            color='black'
        ),
#         bgcolor='#E2E2E2',
#         bordercolor='black',
        borderwidth=1
    ),
    autosize=False,
    width=800,
    height=500,
    margin=go.layout.Margin(
        l=60,
        r=20,
        b=40,
        t=20,
        pad=2
    )
)
fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='Fig1-2')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-2.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 1-3 $sin(x)$ approx

# %%
x = np.linspace(-2.2*np.pi, 2.2*np.pi, 100)
y = np.sin(x)
p1 = x
p3 = p1 - x**3 / factorial(3)
p5 = p3 + x**5 / factorial(5)
p7 = p5 - x**7 / factorial(7)
p9 = p7 + x**9 / factorial(9)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2
    ),
    name = '$sin(x)$'
)
trace1 = go.Scatter(
    x = x,
    y = p1,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2
    ),
    name = '$P_1(x)$'
)
trace2 = go.Scatter(
    x = x,
    y = p3,
    mode = 'lines',
    line = dict(
        color = '#FF8000',
        width = 2
    ),
    name = '$P_3(x)$'
)
trace3 = go.Scatter(
    x = x,
    y = p5,
    mode = 'lines',
    line = dict(
        color = 'green',
        width = 2
    ),
    name = '$P_5(x)$'
)
trace4 = go.Scatter(
    x = x,
    y = p7,
    mode = 'lines',
    line = dict(
        color = 'cyan',
        width = 2
    ),
    name = '$P_7(x)$'
)
trace5 = go.Scatter(
    x = x,
    y = p9,
    mode = 'lines',
    line = dict(
        color = '#7F00FF',
        width = 2
    ),
    name = '$P_9(x)$'
)
data = [trace0, trace1, trace2, trace3, trace4, trace5]

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-2*np.pi, 2*np.pi],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = np.pi,
        mirror = 'ticks',
        title = '$\large x$',
        ticktext=['$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$'],
        tickvals=[-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-2, 2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large y$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
    legend=dict(
        x=0.35,
        y=0.95,
        traceorder='normal',
#         font=dict(
#             family='Arial',
#             size=18
#             color='blue'
#         ),
#         bgcolor='#E2E2E2',
#         bordercolor='black',
#         borderwidth=1
    ),
    autosize=False,
    width=800,
    height=400,
    margin=go.layout.Margin(
        l=30,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='Fig1-3')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-3.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 1-4 Error bar

# %%
x = np.linspace(0, 3, 50)
y = np.exp(x)
x1 = np.linspace(0.25, 2.75, 11)
y1 = np.exp(x1)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'rgba(0,0,255,0.5)',
        width = 2,
        dash = '0.5%'
    )
#     name = '$sin(x)$'
)
trace1 = go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    marker = dict(
        size = 3,
        color = 'blue'
    ),
#     name = '$P_1(x)$'
    error_x=dict(
        type='constant',
        value=0.04,
        visible=True,
        symmetric=True,
        copy_ystyle=True
    ),
    error_y=dict(
        type='percent',
        value=18,
        visible=True,
        symmetric=True,
        color='blue',
        thickness=1.5,
        width=1
    )
)
data = [trace0, trace1]

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 3],
#         exponentformat = 'power',
#         ticks = 'inside',
#         dtick = np.pi,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$'],
#         tickvals=[-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=False,
        showgrid=False
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
#         range = [-2, 2],
#         exponentformat = 'power',
#         ticks = 'inside',
#         dtick = 1,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=False,
        showgrid=False 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=30,
        r=20,
        b=20,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='Fig1-4')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-4.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 1-5 roots

# %%
x = np.linspace(-2.7, 2, 100)
y = x - 0.5 * x**2 - 0.5 * x**3

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'rgba(0,0,255,1)',
        width = 2,
#         shape = spline,
        smoothing = 1
#         dash = '0.5%'
    )
#     name = '$sin(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-2.7, 2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$'],
#         tickvals=[-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-1.7, 2.2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
#     showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig1-5')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-5.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 1-6

# %%
x = np.linspace(0.15, 2.85, 100)
y = -np.log(x)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
#         shape = spline,
        smoothing = 1
#         dash = '0.5%'
    )
#     name = '$sin(x)$'
)
trace1 = go.Scatter(
    x = [0.2, 2.8, 3.1],
    y = [-0.05, -0.05, 0.3],
    mode = 'text',
    text=['$\large a_1$', '$\large b_1$', '$\Large x$'],
    textposition='bottom center'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 3],
#         exponentformat = 'power',
#         ticks = 'inside',
#         dtick = 0.5,
#         mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$'],
#         tickvals=[-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=False,
        zeroline=True,
        showticklabels=False,
        showgrid=False
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-1.5, 2],
#         exponentformat = 'power',
#         ticks = 'inside',
#         dtick = 1,
#         mirror = 'ticks',
        title = '$\large y$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=False,
        zeroline=True,
        showticklabels=False,
        showgrid=False 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1], layout=layout)
py.iplot(fig, filename='Fig1-6')
# iplot(fig)
# pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-6.png', format='png', scale=5)
# print("Done saving image!")

# %% [markdown]
# ## Fig 1-14

# %%
x = np.linspace(-0.5*np.pi, 0.5*np.pi, 250)
y = np.tan(x)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    )
#     name = '$sin(x)$'
)
trace00 = go.Scatter(
    x = x+np.pi,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2,
#         shape = spline,
        smoothing = 1
#         dash = '0.5%'
    )
#     name = '$sin(x)$'
)
trace000 = go.Scatter(
    x = x+2*np.pi,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2,
#         shape = spline,
        smoothing = 1
#         dash = '0.5%'
    )
#     name = '$sin(x)$'
)
trace1 = go.Scatter(
    x = [-np.pi/2-2, 2.5*np.pi+2],
    y = [-np.pi/2-2, 2.5*np.pi+2],
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2
    )
#     textposition='bottom center'
)
trace2 = go.Scatter(
    x = [-np.pi/2, -np.pi/2],
    y = [-10, 10],
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 1,
        dash = '1%'
    )
#     textposition='bottom center'
)
trace3 = go.Scatter(
    x = [np.pi/2, np.pi/2],
    y = [-10, 10],
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 1,
        dash = '1%'
    )
#     textposition='bottom center'
)
trace4 = go.Scatter(
    x = [1.5*np.pi, 1.5*np.pi],
    y = [-10, 10],
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 1,
        dash = '1%'
    )
#     textposition='bottom center'
)
trace5 = go.Scatter(
    x = [2.5*np.pi, 2.5*np.pi],
    y = [-10, 10],
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 1,
        dash = '1%'
    )
#     textposition='bottom center'
)
trace6 = go.Scatter(
    x = [-np.pi/2-0.9, 0.1, np.pi/2+0.1, np.pi-0.1, 1.5*np.pi+0.1, 2*np.pi-0.1, 2.5*np.pi+0.1],
    y = [-0.5]*7,
    mode = 'text',
    text=['$\large -\pi /2$', '$0$', '$\large \pi /2$', '$\large \pi$', '$\large 3\pi /2$', '$\large 2\pi$', '$\large 5\pi /2$'],
    textposition='middle right',
    textfont=dict(
        color = 'black'
    )
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-np.pi+0.2, 3*np.pi-0.2],
#         exponentformat = 'power',
        ticks = 'inside',
#         dtick = np.pi/2,
        mirror = 'ticks',
        title = '$\large x$',
        ticktext=['$\large -\pi /2$', '$0$', '$\large \pi /2$', '$\large \pi$', '$\large 3\pi /2$', '$\large 2\pi$', '$\large 5\pi /2$'],
        tickvals=[-np.pi/2, 0, np.pi/2, np.pi, 1.5*np.pi, 2*np.pi, 2.5*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-10, 10],
#         exponentformat = 'power',
#         ticks = 'inside',
        dtick = 10,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=False 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=40,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace00, trace000, trace1, trace2, trace3, trace4, trace5], layout=layout)
# py.iplot(fig, filename='Fig1-14')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-14.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 1-15

# %%
x = np.linspace(-1.5,3.5,500)
y = x**5 - 5*x**4 + 5*x**3 + 5*x**2 - 6*x - 1

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    )
#     name = '$sin(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-2, 4],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$'],
#         tickvals=[-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-5, 4],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig1-15')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-15.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 1-16 & 1-17

# %%
x = np.linspace(-7*np.pi, 7*np.pi, 500)
y = np.sin(x)/x

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    name = '$sinc(x)$'
)
trace1 = go.Scatter(
    x = x,
    y = np.cos(x),
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    name = '$cos(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-15, 15],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 5,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$'],
#         tickvals=[-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-0.3, 1.1],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large sinc(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig1-16')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-16.png', format='png', scale=5)
print("Done saving image!")

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-7*np.pi, 7*np.pi],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = np.pi,
        mirror = 'ticks',
        title = '$\large x$',
        ticktext=['$-6\pi$', '$-5\pi$', '$-4\pi$', '$-3\pi$', '$-2\pi$', '$-\pi$', '$0$', '$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$'],
        tickvals=[-6*np.pi, -5*np.pi, -4*np.pi, -3*np.pi, -2*np.pi, -np.pi, 0, np.pi, 2*np.pi, 3*np.pi, 4*np.pi, 5*np.pi, 6*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-1.1, 1.3],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
    legend=dict(
        x=0.65,
        y=0.97,
        traceorder='normal',
        font=dict(
#             family='Arial',
            size=13
#             color='blue'
        ),
#         bgcolor='#E2E2E2',
        orientation='h',
        bordercolor='rgb(68, 68, 68)',
        borderwidth=1
    ),
    showlegend=True,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=35,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1], layout=layout)
# py.iplot(fig, filename='Fig1-17')
iplot(fig)
# pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig1-17.png', format='png', scale=5)
# print("Done saving image!")

# %% [markdown]
# ## Fig 2-2

# %%
x = np.linspace(-0.5,1.5,100)

# %%
trace0 = go.Scatter(
    x = x,
    y = -0.1*x**4 - 0.15*x**3 - 0.5*x**2 - 0.25*x + 1.2,
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$sinc(x)$'
)
trace1 = go.Scatter(
    x = [0, 1],
    y = [1.2, 1.2],
    mode = 'lines+markers',
    line = dict(
        color = 'black',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    marker = dict(
        size = 8,
        color = 'black',
        line = dict(
            width = 2,
            color = 'black'
        )
    ),
#     name = '$cos(x)$'
)
trace2 = go.Scatter(
    x = [0, 1],
    y = [1.2, 0.95],
    mode = 'lines+markers',
    line = dict(
        color = 'black',
        width = 2,
#         shape = 'spline',
#         smoothing = 1
#         dash = '0.5%'
    ),
    marker = dict(
        size = 8,
        color = 'black',
        line = dict(
            width = 2,
            color = 'black'
        )
    ),
#     name = '$cos(x)$'
)
trace3 = go.Scatter(
    x = [0, 0.25, 0.5, 1],
    y = [1.2, 1.11, 0.94, 0.45],
    mode = 'lines',
    line = dict(
        color = 'black',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$cos(x)$'
)
trace4 = go.Scatter(
    x = [1],
    y = [0.45],
    mode = 'markers',
    marker = dict(
        size = 8,
        color = 'black',
        line = dict(
            width = 2,
            color = 'black'
        )
    ),
#     name = '$cos(x)$'
)
trace5 = go.Scatter(
    x = [1],
    y = [0.2],
    mode = 'markers',
    marker = dict(
        size = 8,
        color = 'black',
        line = dict(
            width = 2,
            color = 'black'
        )
    ),
#     name = '$cos(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-0.2, 1.3],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
#         mirror = 'ticks',
        title = '$\large x$',
        ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
        tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [0, 1.4],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.5,
#         mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    legend=dict(
        x=0.65,
        y=0.97,
        traceorder='normal',
        font=dict(
#             family='Arial',
            size=13
#             color='blue'
        ),
#         bgcolor='#E2E2E2',
        orientation='h',
        bordercolor='rgb(68, 68, 68)',
        borderwidth=1
    ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1, trace2, trace3, trace4, trace5], layout=layout)
# py.iplot(fig, filename='Fig2-2')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-2.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-5

# %%
x = np.linspace(0, 2.25, 501)
y = 0.1*np.exp(-x)*np.cos(2*np.pi*x)
x1 = np.linspace(0.1, 2.2, 25)
y1 = 0.1*np.exp(-x1)*np.cos(2*np.pi*x1)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$sinc(x)$'
)
trace1 = go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    marker = dict(
        size = 4,
        color = 'blue',
        line = dict(
            width = 1,
            color = 'blue'
        )
    ),
)
trace2 = go.Scatter(
    x = [x1[3], x1[4], x1[8], x1[10], x1[11], x1[13], x1[15], x1[17], x1[18], x1[20], x1[21], x1[22], x1[24]],
    y = [y1[3] + random.uniform(-0.005,0.005), y1[4] + random.uniform(-0.005,0.005), y1[8] + random.uniform(-0.005,0.005), y1[10] + random.uniform(-0.005,0.005), y1[11] + random.uniform(-0.005,0.005), y1[13] + random.uniform(-0.005,0.005), y1[15] + random.uniform(-0.005,0.005), y1[17] + random.uniform(-0.005,0.005), y1[18] + random.uniform(-0.002,0.002), y1[20] + random.uniform(-0.002,0.002), y1[21] + random.uniform(-0.002,0.002), y1[22] + random.uniform(-0.002,0.002), y1[24] + random.uniform(-0.002,0.002)],
    mode = 'markers',
    marker = dict(
        symbol = 'cross-thin-open',
        size = 4,
        color = 'rgb(7, 152, 2)',
        line = dict(
            width = 2,
            color = 'rgb(7, 152, 2)'
        )
    ),
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 2.25],
        ticks = 'inside',
#         dtick = np.pi,
        mirror = 'ticks',
        title = '$\large \mbox{Time } t$',
        ticktext=[0,50,100,150],
        tickvals=np.linspace(0,2.25,4),
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
    ),
    yaxis=dict(
        range = [-0.08, 0.1],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.04,
        mirror = 'ticks',
        title = '$\large I(t)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False 
    ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=55,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1, trace2], layout=layout)
# py.iplot(fig, filename='Fig2-5')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-5.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-16

# %%
x = np.linspace(0,1,101)
y = np.sqrt(1-x**2)
a1, a2, b1, b2 = [], [], [], []
for i in range(1000):
    aa, bb = random.uniform(0,1), random.uniform(0,1)
    if aa**2 + bb**2 <=1:
        a1.append(aa)
        a2.append(bb)
    else:
        b1.append(aa)
        b2.append(bb)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 3,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$sinc(x)$'
)
trace1 = go.Scatter(
    x = a1,
    y = a2,
    mode = 'markers',
    line = dict(
        color = 'red',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    marker = dict(
        size = 3,
        color = 'red',
        line = dict(
            width = 2,
            color = 'red'
        )
    ),
#     name = '$cos(x)$'
)
trace2 = go.Scatter(
    x = b1,
    y = b2,
    mode = 'markers',
    line = dict(
        color = 'green',
        width = 2,
#         shape = 'spline',
#         smoothing = 1
#         dash = '0.5%'
    ),
    marker = dict(
        size = 3,
        color = 'green',
        line = dict(
            width = 2,
            color = 'green'
        )
    ),
#     name = '$cos(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 1],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
#         tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [0, 1],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False 
    ),
#     legend=dict(
#         x=0.65,
#         y=0.97,
#         traceorder='normal',
#         font=dict(
# #             family='Arial',
#             size=13
# #             color='blue'
#         ),
# #         bgcolor='#E2E2E2',
#         orientation='h',
#         bordercolor='rgb(68, 68, 68)',
#         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=400,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1, trace2], layout=layout)
# py.iplot(fig, filename='Fig2-16')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-16.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-20

# %%
a, b = [], []
for i in range(10000):
    a.append(random.uniform(0,1))
    b.append(random.uniform(0,1))

# %%
trace0 = go.Scatter(
    x = a,
    y = b,
    mode = 'markers',
    line = dict(
        color = 'black',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    marker = dict(
        size = 1,
        color = 'black',
        line = dict(
            width = 1,
            color = 'black'
        )
    ),
#     name = '$cos(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 1],
#         exponentformat = 'power',
#         ticks = 'inside',
#         dtick = 0.5,
        mirror = 'ticks',
#         title = '$\large x$',
#         ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
#         tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=False,
        showgrid=False
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [0, 1],
#         exponentformat = 'power',
#         ticks = 'inside',
#         dtick = 0.5,
        mirror = 'ticks',
#         title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=False,
        showgrid=False 
    ),
#     legend=dict(
#         x=0.65,
#         y=0.97,
#         traceorder='normal',
#         font=dict(
# #             family='Arial',
#             size=13
# #             color='blue'
#         ),
# #         bgcolor='#E2E2E2',
#         orientation='h',
#         bordercolor='rgb(68, 68, 68)',
#         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=400,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig2-21')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-21.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-24 & 2-25

# %%
x = np.linspace(-5,5,1001)
y1 = 1/(2*np.pi*0.2)**0.5 * np.exp(-x**2 * 2.5)
y2 = 1/(2*np.pi)**0.5 * np.exp(-x**2 * 0.5)
y3 = 1/(2*np.pi*5)**0.5 * np.exp(-x**2 * 0.1)
y4 = 1/(2*np.pi*0.5)**0.5 * np.exp(-(x+2)**2)

# %%
trace0 = go.Scatter(
    x = x,
    y = y1,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)
trace1 = go.Scatter(
    x = x,
    y = y2,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=1.0$'
)
trace2 = go.Scatter(
    x = x,
    y = y3,
    mode = 'lines',
    line = dict(
        color = 'rgb(218,165,32)',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=5.0$'
)
trace3 = go.Scatter(
    x = x,
    y = y4,
    mode = 'lines',
    line = dict(
        color = 'green',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =-2, \sigma ^2=0.5$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-5.2, 5.2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
#         tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-0.05, 1.05],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    legend=dict(
        x=0.68,
        y=0.97,
        traceorder='normal',
        font=dict(
#             family='Arial',
            size=13
#             color='blue'
        ),
#         bgcolor='#E2E2E2',
        orientation='v',
        bordercolor='rgb(68, 68, 68)',
        borderwidth=1
    ),
    showlegend=True,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1, trace2, trace3], layout=layout)
# py.iplot(fig, filename='Fig2-24')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-24.png', format='png', scale=5)
print("Done saving image!")

# %%
yy1 = norm.cdf(x, 0, np.sqrt(0.2))
yy2 = norm.cdf(x, 0, 1)
yy3 = norm.cdf(x, 0, np.sqrt(5))
yy4 = norm.cdf(x, 0, np.sqrt(0.5))

# %%
trace4 = go.Scatter(
    x = x,
    y = yy1,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)
trace5 = go.Scatter(
    x = x,
    y = yy2,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=1.0$'
)
trace6 = go.Scatter(
    x = x,
    y = yy3,
    mode = 'lines',
    line = dict(
        color = 'rgb(218,165,32)',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=5.0$'
)
trace7 = go.Scatter(
    x = x,
    y = yy4,
    mode = 'lines',
    line = dict(
        color = 'green',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =-2, \sigma ^2=0.5$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-5.2, 5.2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
#         tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-0.05, 1.05],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    legend=dict(
        x=0.03,
        y=0.97,
        traceorder='normal',
        font=dict(
#             family='Arial',
            size=13
#             color='blue'
        ),
#         bgcolor='#E2E2E2',
        orientation='v',
        bordercolor='rgb(68, 68, 68)',
        borderwidth=1
    ),
    showlegend=True,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace4, trace5, trace6, trace7], layout=layout)
# py.iplot(fig, filename='Fig2-25')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-25.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-26

# %%
x = np.linspace(-5, 5, 1001)
y1 = 1/(2*np.pi)**0.5 * np.exp(-x**2 * 0.5)
y2 = norm.cdf(x, 0, 1)

# %%
trace0 = go.Scatter(
    x = x,
    y = y1,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)
trace1 = go.Scatter(
    x = x,
    y = y2,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    xaxis='x2',
    yaxis='y2',
#     name = '$\mu =0, \;\;\, \sigma ^2=1.0$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        domain=[0, 0.45],
        range = [-5.1, 5.1],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 2,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
#         tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
#         domain=[0, 0.45],
        range = [0, 0.5],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.1,
        mirror = 'ticks',
        title = '$\large P(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    xaxis2=dict(
        domain=[0.55, 1],
        range = [-5.1, 5.1],
        ticks = 'inside',
        dtick = 2,
        mirror = 'ticks',
        title = '$\large x$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis2=dict(
#         domain=[0, 0.45],
        range = [0, 1],
        anchor='x2',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large D(x)$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    showlegend=False,
    autosize=False,
    width=1000,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1], layout=layout)
# py.iplot(fig, filename='Fig2-26')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-26.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-27

# %%
theta = np.linspace(0, 2*np.pi, 10001)
x1, y1 = np.cos(theta), np.sin(theta)
x2, y2 = 0.9*x1, 0.9*y1
x3, y3 = 0.8*x1, 0.8*y1
x4, y4 = 0.7*x1, 0.7*y1
x5, y5 = 0.6*x1, 0.6*y1
x6, y6 = 0.5*x1, 0.5*y1
x7, y7 = 0.4*x1, 0.4*y1
x8, y8 = 0.3*x1, 0.3*y1
x9, y9 = 0.2*x1, 0.2*y1
x10, y10 = 0.1*x1, 0.1*y1

# %%
trace1 = go.Scatter(
    x = x1,
    y = y1,
    mode = 'lines',
    line = dict(
        color = '#FF6666',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace2 = go.Scatter(
    x = x2,
    y = y2,
    mode = 'lines',
    line = dict(
        color = '#FFB266',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace3 = go.Scatter(
    x = x3,
    y = y3,
    mode = 'lines',
    line = dict(
        color = '#FFFF66',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace4 = go.Scatter(
    x = x4,
    y = y4,
    mode = 'lines',
    line = dict(
        color = '#B2FF66',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace5 = go.Scatter(
    x = x5,
    y = y5,
    mode = 'lines',
    line = dict(
        color = '#66FF66',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace6 = go.Scatter(
    x = x6,
    y = y6,
    mode = 'lines',
    line = dict(
        color = '#66FFB2',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace7 = go.Scatter(
    x = x7,
    y = y7,
    mode = 'lines',
    line = dict(
        color = '#66FFFF',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace8 = go.Scatter(
    x = x8,
    y = y8,
    mode = 'lines',
    line = dict(
        color = '#66B2FF',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace9 = go.Scatter(
    x = x9,
    y = y9,
    mode = 'lines',
    line = dict(
        color = '#6666FF',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)
trace10 = go.Scatter(
    x = x10,
    y = y10,
    mode = 'lines',
    line = dict(
        color = '#B266FF',
        width = 2,
        shape = 'spline',
        smoothing = 1
    ),
)

# %%
layout = {
    xaxis=dict(
#         domain=[0, 0.45],
        range = [-1.1, 1.1],
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
#         title = '$\large x$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
#         domain=[0.6, 1],
        range = [-1.1, 1.1],
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
#         title = '$\large P(x)$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
#     xaxis2=dict(
#         range = [-7, 7],
#         ticks = 'inside',
#         dtick = 2,
#         mirror = 'ticks',
# #         title = '$\large x$',
#         showline=True,
#         zeroline=False,
#         showticklabels=True,
#         showgrid=True
#     ),
#     yaxis2=dict(
#         domain=[0, 0.4],
#         range = [-7, 7],
#         anchor='x2',
#         ticks = 'inside',
#         dtick = 2,
#         mirror = 'ticks',
# #         title = '$\large D(x)$',
#         showline=True,
#         zeroline=False,
#         showticklabels=True,
#         showgrid=True 
#     ),
    showlegend=False,
    autosize=False,
    width=400,
    height=1000,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
}
fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10], layout=layout)
# py.iplot(fig, filename='Fig2-27')
iplot(fig)
# pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-27.png', format='png', scale=5)
# print("Done saving image!")

# %% [markdown]
# ## Fig 2-29

# %%
x = np.linspace(-5,5,1001)
y1 = 1/(2*np.pi*0.2)**0.5 * np.exp(-x**2 * 2.5)
y2 = 1/(2*np.pi)**0.5 * np.exp(-x**2 * 0.5)
y3 = 1/(2*np.pi*5)**0.5 * np.exp(-x**2 * 0.1)
y4 = 1/(2*np.pi*0.5)**0.5 * np.exp(-(x+2)**2)

# %%
trace0 = go.Scatter(
    x = x,
    y = y1,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)
trace1 = go.Scatter(
    x = x,
    y = y2,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=1.0$'
)
trace2 = go.Scatter(
    x = x,
    y = y3,
    mode = 'lines',
    line = dict(
        color = 'rgb(218,165,32)',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =0, \;\;\, \sigma ^2=5.0$'
)
trace3 = go.Scatter(
    x = x,
    y = y4,
    mode = 'lines',
    line = dict(
        color = 'green',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
    name = '$\mu =-2, \sigma ^2=0.5$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-5.2, 5.2],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 1,
        mirror = 'ticks',
        title = '$\large x$',
#         ticktext=['$x_i =0$', '$x_{i+1} = 1$'],
#         tickvals=[0, 1],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-0.05, 1.05],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    legend=dict(
        x=0.68,
        y=0.97,
        traceorder='normal',
        font=dict(
#             family='Arial',
            size=13
#             color='blue'
        ),
#         bgcolor='#E2E2E2',
        orientation='v',
        bordercolor='rgb(68, 68, 68)',
        borderwidth=1
    ),
    showlegend=True,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1, trace2, trace3], layout=layout)
# py.iplot(fig, filename='Fig2-24')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-24.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-30

# %%
x = np.linspace(-6,6,1001)
y = 1/(1+np.exp(-x))

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-6, 6],
        ticks = 'inside',
        dtick = 2,
        mirror = 'ticks',
        title = '$\large x$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
        range = [0, 1],
        ticks = 'inside',
        dtick = 0.5,
        mirror = 'ticks',
        title = '$\large S(x)$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig2-30')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-30.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-31

# %%
x = np.linspace(-4*np.pi, 4*np.pi, 301)
y = np.sin(x)/x

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'red',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    name = '$sinc(x)$'
)
trace1 = go.Scatter(
    x = x,
    y = np.cos(x),
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
#         shape = spline,
#         smoothing = 1
#         dash = '0.5%'
    ),
    name = '$cos(x)$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-4*np.pi, 4*np.pi],
        ticks = 'inside',
#         dtick = np.pi,
        mirror = 'ticks',
        title = '$\large x$',
        ticktext=['$-4\pi$', '$-3\pi$', '$-2\pi$', '$-\pi$', 0, '$\pi$', '$2\pi$', '$3\pi$', '$4\pi$'],
        tickvals=[-4*np.pi, -3*np.pi, -2*np.pi, -np.pi, 0, np.pi, 2*np.pi, 3*np.pi, 4*np.pi],
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=25
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range = [-0.3, 1.1],
#         exponentformat = 'power',
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large f(x)$',
#         type = 'log',
#         titlefont=dict(
#             family='Arial'
#             size=20
#             color='#7f7f7f'
#         ),
#         tickfont=dict(
#             family='Times New Roman',
#             size=18
#             color='#7f7f7f'
#         ),
#         automargin=True,
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
#     legend=dict(
#         x=0.35,
#         y=0.95,
#         traceorder='normal',
# #         font=dict(
# #             family='Arial',
# #             size=18
# #             color='blue'
# #         ),
# #         bgcolor='#E2E2E2',
# #         bordercolor='black',
# #         borderwidth=1
#     ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=45,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig2-31')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-31.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-35

# %%
theta = np.linspace(0,np.pi,501)
r = np.sin(2*theta)
x = r*np.cos(theta)
y = r*np.sin(theta)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)
trace1 = go.Scatter(
    x = -x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-0.9, 0.9],
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large x$',
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
        range = [-0.9, 0.9],
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large y$',
        showline=True,
        zeroline=True,
        showticklabels=True,
        showgrid=True 
    ),
    showlegend=False,
    autosize=False,
    width=600,
    height=600,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0, trace1], layout=layout)
# py.iplot(fig, filename='Fig2-35')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-35.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## Fig 2-36

# %%
x = np.linspace(0.0001,0.9999,200)
y = np.log(x)*np.log(1-x)

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 2,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [-0.05, 1.05],
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large x$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
        range = [-0.05, 0.5],
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large y$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    showlegend=False,
    autosize=False,
    width=800,
    height=400,
    margin=go.layout.Margin(
        l=40,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0], layout=layout)
# py.iplot(fig, filename='Fig2-36')
iplot(fig)
pio.write_image(fig, 'C:/Users/garyh/OneDrive/TEXTBOOK/NC/fig2-36.png', format='png', scale=5)
print("Done saving image!")

# %% [markdown]
# ## T1/T1

# %%
x = np.linspace(0,1,101)
y = (3 + 4 * x + 8 * x**2)/(3 * x**2 + 4 * x + 8)
print(x[60],y[60])

# %%
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    line = dict(
        color = 'blue',
        width = 1,
        shape = 'spline',
        smoothing = 1
#         dash = '0.5%'
    ),
#     name = '$\mu =0, \;\;\, \sigma ^2=0.2$'
)
trace1 = go.Scatter(
    x = [0,x[40],1],
    y = [3/8,y[40],1],
    mode = 'markers',
    marker = dict(
        size = 8,
        color = 'blue'
    )
)
trace3 = go.Scatter(
    x=[0.04,0.96],
    y=[3/8-0.03,1.03],
    mode='text',
    text=['$(0,3/8)$', '$(1,1)$'],
    textposition='middle center',
    textfont=dict(
#         family='sans serif',
        size=12,
#         color='#ff7f0e'
    )
)

# %%
layout = go.Layout(
    xaxis=dict(
        range = [0, 1],
        ticks = 'inside',
        dtick = 0.2,
        mirror = 'ticks',
        title = '$\large r/R$',
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True
    ),
    yaxis=dict(
        range = [0, 1.1],
        ticks = 'inside',
        dtick = 0.25,
        mirror = 'ticks',
        title = '$\large T_{2}/T_{1}$',
#         ticktext=[0, '3/8', 1],
#         tickvals=[0, 3/8, 1],
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True 
    ),
    showlegend=False,
    autosize=False,
    width=600,
    height=400,
    margin=go.layout.Margin(
        l=60,
        r=20,
        b=30,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace0,trace1,trace3], layout=layout)
# py.iplot(fig, filename='Fig')
iplot(fig)
pio.write_image(fig, '/Users/gary/Desktop/fig.png', format='png', scale=5)
# print("Done saving image!")
