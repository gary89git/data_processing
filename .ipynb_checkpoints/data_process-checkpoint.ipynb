# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Velocity-Profile" data-toc-modified-id="Velocity-Profile-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Velocity Profile</a></span></li><li><span><a href="#RMSD-(txt)" data-toc-modified-id="RMSD-(txt)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>RMSD (txt)</a></span></li><li><span><a href="#RMSD-(xlrd)" data-toc-modified-id="RMSD-(xlrd)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>RMSD (xlrd)</a></span></li></ul></div>

# %% [markdown]
# # Data Processing

# %%
import numpy as np
import os
import xlrd
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as pl
from plotly.offline import iplot, plot, init_notebook_mode
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.io as pio
import plotly
plotly.tools.set_credentials_file(username='garyhan', api_key='jb6utiwqOF7F3bAuf1Td')
init_notebook_mode(connected=True)

import math
from math import factorial
from math import sin
from math import cos
from math import log
from math import exp
from math import sinh
#import Image
import numpy as np
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
os.chdir('/Users/gary/OneDrive/Research/Platelets/results/')
# os.chdir('D:/OneDrive/Research/Platelets/results/')
# os.listdir('.')

# %%
def get_cell_range(start_row, end_row, start_col, end_col):
    return [sheet.row_slice(row, start_colx=start_col, end_colx=end_col+1) for row in range(start_row, end_row+1)]

# %% [markdown]
# ## Velocity Profile

# %%
file = 'velocity.xlsx'
vel = pd.read_excel(file)
# print(vel.shape)
df = pd.DataFrame(vel)
# print(df)
# print(df.iloc[0:,2:4])

# %%
reg = LinearRegression().fit(df.iloc[:,2].values.reshape(-1,1), df.iloc[:,4].values.reshape(-1,1))
print('intercept: ', reg.intercept_)
print('slope: ', reg.coef_)
y_fit = reg.predict(np.array(range(-45,1)).reshape(-1,1))
# Out:
# intercept:  [0.10793341]
# slope:  [[0.00234948]]

# %%
trace0 = go.Scatter(
    y = df.iloc[:,2],
    x = df.iloc[:,4],
    mode = 'lines+markers',
    line = dict(color = 'green'),
    name = 'velocity'
)
trace1 = go.Scatter(
    y = np.array(range(-45,1)),
    x = y_fit,
    line = dict(
        color = 'red',
        width = 4,
        dash = 'dot'),
    name = 'fitted line'
)
data = [trace0,trace1]
layout = go.Layout(
    xaxis=dict(
        range=[0, 0.12],
        title='Velocity',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
        showline=True,
        zeroline=False,
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
        rangeslider=dict(
            visible = True
        )
    ),
    yaxis=dict(
        range=[-45, 1],
        title='Height',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
        showline=True,
        zeroline=False
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Velocity Profile')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~garyhan/0 or inside your plot.ly account where it is named 'Velocity Profile'
# D:\Software\Anaconda3\envs\py37\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~garyhan/0.embed" height="525px" width="100%"></iframe>

# %%
shear_stress = 200 * (0.1/45) * (12.06/0.5333)
print('shear stress: ', shear_stress)
# Out:
# shear stress:  10.050628164260266

# %% [markdown]
# ## RMSD (txt)

# %%
df = pd.read_csv('/Users/gary/Downloads/simulation/mapping/rmsd.txt', sep=",", header=0)

# %%
trace0 = go.Scatter(
    x = df.iloc[:,2],
    y = df.iloc[:,4],
    mode = 'lines',
    line = dict(color = 'blue'),
    name = 'RMSDX'
)
trace1 = go.Scatter(
    x = df.iloc[:,2],
    y = df.iloc[:,6],
    line = dict(
        color = 'red',
        width = 1,
#         dash = 'dot'
    ),
    name = 'RMSDV',
    yaxis='y2'
)

# %%
data = [trace0,trace1]
layout = go.Layout(
    xaxis=dict(
#         range=[0, 0.12],
        ticks = 'inside',
#         dtick = 6,
        mirror = 'ticks',
        title='$\mbox{Simulated Time } (\mu s)$',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True,
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range=[0, 0.03],
        title='$\mbox{RMSDX }(\mu m)$',
        ticks = 'inside',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
        titlefont=dict(
            color='blue'
        ),
        tickfont=dict(
            color='blue'
        ),
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
    ),
    yaxis2=dict(
        range=[0, 1],
        title='$\mbox{RMSDV }(cm/s)$',
        ticks = 'inside',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
#         showline=True,
        zeroline=False,
#         showticklabels=True,
#         showgrid=True,
        titlefont=dict(
            color='red'
        ),
        tickfont=dict(
            color='red'
        ),
        overlaying='y',
        side='right',
        showline=True,
    ),
    legend=dict(
        x=0.85,
        y=0.95,
        traceorder='normal',
        font=dict(
#             family='Arial',
#             size=20,
            color='black'
        ),
#         bgcolor='#E2E2E2',
#         bordercolor='black',
        borderwidth=1
    ),
    showlegend=True,
    autosize=False,
    width=1000,
    height=500,
    margin=go.layout.Margin(
        l=60,
        r=60,
        b=40,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace1,trace0], layout=layout)
# py.iplot(fig, filename='RMSD & RMSV')
iplot(fig)
# pio.write_image(fig, 'rmsd.png', format='png', scale=5)
# print("Done saving image!")
# Out:
# <div id="8fa37eb7-1938-4ad0-a2bc-ce9f4fe822ef" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8fa37eb7-1938-4ad0-a2bc-ce9f4fe822ef", [{"line": {"color": "red", "width": 1}, "name": "RMSDV", "x": [0.0, 0.10400000000000001, 0.20800000000000002, 0.312, 0.41600000000000004, 0.52, 0.624, 0.728, 0.8320000000000001, 0.9359999999999999, 1.04, 1.1440000000000001, 1.248, 1.3519999999999999, 1.456, 1.56, 1.6640000000000001, 1.768, 1.8719999999999999, 1.976, 2.08, 2.184, 2.2880000000000003, 2.392, 2.496, 2.6, 2.7039999999999997, 2.8080000000000003, 2.912, 3.016, 3.12, 3.2239999999999998, 3.3280000000000003, 3.432, 3.536, 3.64, 3.7439999999999998, 3.8480000000000003, 3.952, 4.056, 4.16, 4.263999999999999, 4.368, 4.4719999999999995, 4.5760000000000005, 4.68, 4.784, 4.888, 4.992, 5.096, 5.2, 5.303999999999999,
# ...

# %% [markdown]
# ## RMSD (xlrd)

# %%
workbook = xlrd.open_workbook("flip-agg.xlsx")
# sheet = workbook.sheet_by_index(0)
sheet = workbook.sheet_by_name("rmsd")

# %%
trace0 = go.Scatter(
    x = sheet.col_values(3,1),
    y = sheet.col_values(5,1),
    mode = 'lines',
    line = dict(color = 'blue'),
    name = 'RMSDX'
)
trace1 = go.Scatter(
    x = sheet.col_values(3,1),
    y = sheet.col_values(7,1),
    line = dict(
        color = 'red',
        width = 1,
#         dash = 'dot'
    ),
    name = 'RMSDV',
    yaxis='y2'
)

# %%
data = [trace0,trace1]
layout = go.Layout(
    xaxis=dict(
#         range=[0, 0.12],
        ticks = 'inside',
#         dtick = 6,
        mirror = 'ticks',
        title='$\mbox{Simulated Time } (\mu s)$',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=True,
#     rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=1,
#                     label='YTD',
#                     step='year',
#                     stepmode='todate'),
#                 dict(count=1,
#                     label='1y',
#                     step='year',
#                     stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         )
    ),
    yaxis=dict(
        range=[0, 0.05],
        title='$\mbox{RMSDX }(\mu m)$',
        ticks = 'inside',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
        titlefont=dict(
            color='blue'
        ),
        tickfont=dict(
            color='blue'
        ),
        showline=True,
        zeroline=False,
        showticklabels=True,
        showgrid=False
    ),
    yaxis2=dict(
        range=[0, 1],
        title='$\mbox{RMSDV }(cm/s)$',
        ticks = 'inside',
#         titlefont=dict(
#             family='Courier New, monospace',
#             size=18,
#             color='#7f7f7f'
#         ),
#         showline=True,
        zeroline=False,
#         showticklabels=True,
#         showgrid=True,
        titlefont=dict(
            color='red'
        ),
        tickfont=dict(
            color='red'
        ),
        overlaying='y',
        side='right',
        showline=True,
    ),
    legend=dict(
        x=0.03,
        y=0.97,
        traceorder='normal',
        font=dict(
#             family='Arial',
#             size=20,
            color='black'
        ),
#         bgcolor='#E2E2E2',
#         bordercolor='black',
        borderwidth=1
    ),
    showlegend=True,
    autosize=False,
    width=1000,
    height=500,
    margin=go.layout.Margin(
        l=60,
        r=60,
        b=40,
        t=20,
        pad=0
    )
)
fig = go.Figure(data=[trace1,trace0], layout=layout)
# py.iplot(fig, filename='RMSD & RMSV')
iplot(fig)
pio.write_image(fig, 'rmsd.png', format='png', scale=5)
print("Done saving image!")
# Out:
# <div id="369f93e5-2995-4397-a79f-d51a40ce8d66" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("369f93e5-2995-4397-a79f-d51a40ce8d66", [{"line": {"color": "red", "width": 1}, "name": "RMSDV", "x": [0.0, 0.104, 0.208, 0.312, 0.416, 0.52, 0.624, 0.728, 0.832, 0.936, 1.04, 1.144, 1.248, 1.352, 1.456, 1.56, 1.664, 1.768, 1.872, 1.976, 2.08, 2.184, 2.288, 2.392, 2.496, 2.6, 2.704, 2.808, 2.912, 3.016, 3.12, 3.224, 3.328, 3.432, 3.536, 3.64, 3.744, 3.848, 3.952, 4.056, 4.16, 4.264, 4.368, 4.472, 4.576, 4.68, 4.784, 4.888, 4.992, 5.096, 5.2, 5.304, 5.408, 5.512, 5.616, 5.72, 5.824, 5.928, 6.032, 6.136, 6.24, 6.344, 6.448, 6.552, 6.656, 6.76, 6.864, 6.968, 7.072, 7.176, 7.28, 7.384, 7.488, 7.592, 7.696, 7.8, 7.904, 8.008, 8.112, 8.216, 8.32, 8.424, 8.528, 8.632, 8.736, 8.84, 8.944, 9.048, 9.152, 9.256, 9.
# ...
